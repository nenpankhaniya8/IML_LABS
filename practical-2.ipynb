# %% [markdown]
# # to convert a list of numeric values into a one-dimensional NumPy array

# %%
# 216270307008
# pankhaniya nensi

import numpy as np

list=[1,2,3,4,5]
Array = np.array(list)
print(Array)

# %% [markdown]
# # to create a 3x3 matrix with values ranging from 2 to 10

# %%
# 216270307008
# pankhaniya nensi

import numpy as np

values =np.arange(2,11)
matrix=values.reshape(3,3)
print(matrix)

# %% [markdown]
# # to append values at the end of an array

# %%
# 216270307008
# pankhaniya nensi

import numpy as np

x=[10 , 20, 30]
print(x)

x = np.append(x,[[40, 50,60],[70, 80, 90]])
print("after append values to the the end of the array:")
print()

# %% [markdown]
# # to create another shape from an array without changing its data(3*2 to 2*3)

# %%
# 216270307008
# pankhaniya nensi

import numpy as np

original_array = np.array([[1,2],[3,4],[5,6]])
reshapend_array = original_array .reshape(2,3)

print("Original array:")
print(original_array )
print("\nReshaped array:")
print(reshapend_array )
